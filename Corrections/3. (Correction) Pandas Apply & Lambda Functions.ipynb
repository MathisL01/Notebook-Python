# %%
import pandas as pd

# %% [markdown]
# ### Welcome to the Apply Challenge

# %%
link = 'https://raw.githubusercontent.com/chriszapp/datasets/main/books.csv'
books = pd.read_csv(link, nrows = 13)
books.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
# Firstly, have a look at the dataset

# %%
# Mission 1: use apply to create a new column called 'reviews_opinion': if the ratings is between 4.5 and 5, the reviews_opinion is 'very good';
# if the rating is between 4 and 4.5, the reviews_opinion is 'good'; if the rating is between 3 and 4, the reviews_opinions will be 'neutral';
# if the rating is up to 3 the reviews_opinion is going to be 'bad'

# Add your code here

def reviews_opinion(col):
    if 4.5 < col["average_rating"] < 5: 
        return "very good"
    elif 4 < col["average_rating"] < 4.5:
        return "good"
    elif 4 < col["average_rating"] < 3:
        return "neutral"
    elif col["average_rating"] < 3:
        return "bad"
    
books['reviews_opinion'] = books.apply(reviews_opinion, axis = 1)
books.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher reviews_opinion
# 0        9/16/2006  Scholastic Inc.       very good
# 1         9/1/2004  Scholastic Inc.            good
# 2        11/1/2003       Scholastic            good
# 3         5/1/2004  Scholastic Inc.       very good
# 4        9/13/2004       Scholastic       very good

# %%
# Mission 2: using apply with a function, create a column with the number of authors per book
# (note that in the column 'authors', each name of the author is divided with the character '/')

# Add your code here


books['nb_authors'] = books['authors'].apply(lambda x: len(x.split('/')))
# books['nb_authors'] = books['authors'].apply(lambda x: x.count('/')+1)
books.head(2)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
#
#   publication_date        publisher reviews_opinion  nb_authors
# 0        9/16/2006  Scholastic Inc.       very good           2
# 1         9/1/2004  Scholastic Inc.            good           2

# %%
# Mission 3: rewrite the same task as Mission 2 using the lamdba function

# Add your code here

# %%
# Mission 4: create a column 'comment_ratio'.
# Use the columns 'ratings_count' and 'text_reviews_count' to calculate the percentage of how many text review per reviews are per book:
# percentage = text / reviews * 100
# Use the mathematical operations between columns

# Add your code here

books['comment_ratio'] = (books['text_reviews_count'] / books['ratings_count']) * 100
books.head(1)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
#
#   publication_date        publisher reviews_opinion  nb_authors  comment_ratio
# 0        9/16/2006  Scholastic Inc.       very good           2       1.316559

# %%
# Mission 5: obtain the same result of Mission 4 using apply with a function.
# Try both methods to apply to the whole dataset and apply to selected columns

# Add your code here

def comment_ratio(df):
    return (df['text_reviews_count'] / df['ratings_count']) * 100

# books['comment_ratio'] = (books['text_reviews_count'] / books['ratings_count']) * 100

books['comment_ratio'] = books.apply(comment_ratio, axis=1)

books.head(1)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
#
#   publication_date        publisher reviews_opinion  nb_authors  comment_ratio
# 0        9/16/2006  Scholastic Inc.       very good           2       1.316559

# %%
# Mission 6: obtain the same result of Mission 5 using apply lambda
# Try both methods to apply to the whole dataset and apply to selected columns

# Add your code here

books['comment_ratio'] = books\
    .apply(lambda df: (df['text_reviews_count'] / df['ratings_count']) * 100, axis=1)
books.head(1)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
#
#   publication_date        publisher reviews_opinion  nb_authors  comment_ratio
# 0        9/16/2006  Scholastic Inc.       very good           2       1.316559

# %%
# Mission 7: extract the year from the publication_date column. How many years of publications are recorded in this dataset? Which are them?

# Add your code here
import datetime

books['publication_date'] = pd.to_datetime(books['publication_date'])

# print(books.dtypes)
books.head(1)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
#
#   publication_date        publisher reviews_opinion  nb_authors  comment_ratio
# 0       2006-09-16  Scholastic Inc.       very good           2       1.316559

# %%
from datetime import datetime

my_time_object = datetime.strptime('2006-09-16', '%Y-%m-%d')
print(my_time_object)
my_time_object.strftime('%Y-%m-%d')
# Out:
# 2006-09-16 00:00:00
# '2006-09-16'

# %%
# books['publication_date'].dt.strftime('%Y')

books['publication_year'] = books\
    .apply(lambda x: x['publication_date'].year, axis=1)
books.head(2)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
#
#   publication_date        publisher reviews_opinion  nb_authors  \
# 0       2006-09-16  Scholastic Inc.       very good           2
# 1       2004-09-01  Scholastic Inc.            good           2
#
#    comment_ratio  publication_year
# 0       1.316559              2006
# 1       1.357117              2004
